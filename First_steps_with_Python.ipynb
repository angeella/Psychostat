# %% [markdown]
# # <span style="color:red"> FOREST FIRES IN BRAZIL </span>

# %% [markdown]
# See <https://www.kaggle.com/gustavomodelli/forest-fires-in-brazil> for a full description of the dataset.

# %% [markdown]
# Import packages

# %%
#Magic function to see the plot in the notebook inline
# %matplotlib inline 
import pandas as pd #Handle datasets
import seaborn as sns #Plots
import matplotlib.pyplot as plt  #Plots
import matplotlib

# %% [markdown]
# Instead of %matplotlib inline, you can use %matplotlib notebook that will lead to interactive plots embedded within the notebook

# %% [markdown]
# Set some graphical parameters regarding **seaborn** plot:

# %%
rc={'axes.labelsize': 25, 'figure.figsize': (20,10), 
    'axes.titlesize': 25, 'xtick.labelsize': 18, 'ytick.labelsize': 18}
sns.set(rc=rc)

# %% [markdown]
# Import data

# %%
path = 'C:/Users/Angela Andreella/Documents/Conference_Talk/Python_Psicostat1/' #your path
df = pd.read_csv(path + 'Data/amazon.csv')

# %% [markdown]
# First $3$ **observations**:

# %%
df.head(n=3)
# Out:
#    year state    month  number        date
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01

# %% [markdown]
# Some **information** about the variables:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
# year      6454 non-null int64
# state     6454 non-null object
# month     6454 non-null object
# number    6454 non-null float64
# date      6454 non-null object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 252.2+ KB

# %%
df.shape
# Out:
# (6454, 5)

# %% [markdown]
# We have $6454$ observations and $5$ variables: year, state, month, number and date.

# %% [markdown]
# We are interested about the **number of forest fires** in Brazil:

# %%
df.number.describe()
# Out:
# count    6454.000000
# mean      108.293163
# std       190.812242
# min         0.000000
# 25%         3.000000
# 50%        24.000000
# 75%       113.000000
# max       998.000000
# Name: number, dtype: float64

# %% [markdown]
# To have a simple plot, we take a **subset** of the dataset, selecting the observations from 2014 until 2019 regarding the country with name starting with "M" or "B":

# %%
df1 = df[(df.year > 2013) & (df.year < 2020)]
df1 =df1.loc[(df1.state.str.startswith('M') | df1.state.str.startswith('B'))]
df1.shape
# Out:
# (235, 5)

# %% [markdown]
# So, now we have $253$ observations.

# %% [markdown]
# The **.loc** function permits to access a group of rows and columns by label(s) or a boolean array in the pandas dataframe, or we can use the boolean expression.

# %% [markdown]
# We do a **boxplot** about the number of fire by groups, i.e., the **states** and the **years**.

# %%
sns.boxplot(x = 'state', y = 'number', hue = "year", data = df1)

# %% [markdown]
# also we do a **grouped violinplots**:

# %%
sns.violinplot(x="state", y="number", data=df1)

# %%
df1.loc[(df1.state.str.startswith('Mato Grosso'))].describe()
# Out:
#               year      number
# count    94.000000   94.000000
# mean   2015.468085  228.360957
# std       1.113960  276.741751
# min    2014.000000    1.018000
# 25%    2014.250000    3.821250
# 50%    2015.000000  128.000000
# 75%    2016.000000  362.500000
# max    2017.000000  960.000000

# %% [markdown]
# For other plots, please see <https://seaborn.pydata.org/examples/index.html>.

# %% [markdown]
# To know the different type of matplotlib style:

# %%
matplotlib.style.available
# Out:
# ['seaborn-darkgrid',
#  'Solarize_Light2',
#  'seaborn-notebook',
#  'classic',
#  'seaborn-ticks',
#  'grayscale',
#  'bmh',
#  'seaborn-talk',
#  'dark_background',
#  'ggplot',
#  'fivethirtyeight',
#  '_classic_test',
#  'seaborn-colorblind',
#  'seaborn-deep',
#  'seaborn-whitegrid',
#  'seaborn-bright',
#  'seaborn-poster',
#  'seaborn-muted',
#  'seaborn-paper',
#  'seaborn-white',
#  'fast',
#  'seaborn-pastel',
#  'seaborn-dark',
#  'tableau-colorblind10',
#  'seaborn',
#  'seaborn-dark-palette']

# %%
plt.style.use('ggplot')

# %% [markdown]
# The style of the seaborn package are darkgrid, whitegrid, dark, white, and ticks, we can set it using

# %%
sns.set_style("whitegrid")
sns.violinplot(x="state", y="number", data=df1)

# %% [markdown]
# If you want to see what parameters are included, you can just call the function:

# %%
sns.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': '.8',
#  'axes.facecolor': 'white',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.spines.bottom': True,
#  'axes.spines.left': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True,
#  'figure.facecolor': 'white',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'image.cmap': 'rocket',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'text.color': '.15',
#  'xtick.bottom': False,
#  'xtick.color': '.15',
#  'xtick.direction': 'out',
#  'xtick.top': False,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.left': False,
#  'ytick.right': False}

# %% [markdown]
# To reset the default parameters: sns.set()

# %% [markdown]
# We have also the possibility to set the graphical parameters having a paper, notebook, talk, or poster.

# %%
sns.set()
sns.set_context("paper")
sns.violinplot(x="state", y="number", data=df1)

# %% [markdown]
# We reset the graphical parameters as before

# %%
sns.set(rc=rc)

# %% [markdown]
# # <span style="color:red"> ECONOMIC FREEDOM INDEX</span>

# %% [markdown]
# See <https://www.kaggle.com/lewisduncan93/the-economic-freedom-index> for a full description of the dataset.

# %% [markdown]
# Load data

# %%
dt = pd.read_csv(path + 'Data/economic_freedom_index2019_data.csv')
for col in dt.columns: 
    print(col)
# Out:
# CountryID
# Country Name
# WEBNAME
# Region
# World Rank
# Region Rank
# 2019 Score
# Property Rights
# Judical Effectiveness
# Government Integrity
# Tax Burden
# Gov't Spending
# Fiscal Health
# Business Freedom
# Labor Freedom
# Monetary Freedom
# Trade Freedom
# Investment Freedom
# Financial Freedom
# Tariff Rate (%)
# Income Tax Rate (%)
# Corporate Tax Rate (%)
# Tax Burden % of GDP
# Gov't Expenditure % of GDP
# Country
# Population (Millions)
# GDP (Billions, PPP)
# GDP Growth Rate (%)
# 5 Year GDP Growth Rate (%)
# GDP per Capita (PPP)
# Unemployment (%)
# Inflation (%)
# FDI Inflow (Millions)
# Public Debt (% of GDP)

# %% [markdown]
# Preprocess data

# %%
dt.columns = dt.columns.str.replace(' ', '')
dt.columns = dt.columns.str.replace('2019', '')
dt.columns = dt.columns.str.replace('%', '')
dt.columns = dt.columns.str.replace('(', '')
dt.columns = dt.columns.str.replace(')', '')
dt = dt.dropna(axis = 0,how='any')

# %% [markdown]
# Basic info

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173 entries, 0 to 185
# Data columns (total 34 columns):
# CountryID                173 non-null int64
# CountryName              173 non-null object
# WEBNAME                  173 non-null object
# Region                   173 non-null object
# WorldRank                173 non-null float64
# RegionRank               173 non-null float64
# Score                    173 non-null float64
# PropertyRights           173 non-null float64
# JudicalEffectiveness     173 non-null float64
# GovernmentIntegrity      173 non-null float64
# TaxBurden                173 non-null float64
# Gov'tSpending            173 non-null float64
# FiscalHealth             173 non-null float64
# BusinessFreedom          173 non-null float64
# LaborFreedom             173 non-null float64
# MonetaryFreedom          173 non-null float64
# TradeFreedom             173 non-null float64
# InvestmentFreedom        173 non-null float64
# ...

# %% [markdown]
# ## <span style="color:blue"> Plots </span>

# %% [markdown]
# We are interest in the score of the **Economic Freedom Index**, an index that describe 12 freedoms – from property rights to financial freedom – in 186 countries.
# At first, we do the **boxplot** by group, i.e. **region**:

# %%
sns.boxplot(x = 'Region', y = 'Score', data = dt)

# %% [markdown]
# and a **scatter plot**:

# %%
plt.scatter(x="PropertyRights", y="Score", data=dt)

# %% [markdown]
# We can put directly the **linear regression fitting**:

# %%
sns.lmplot(x="PropertyRights", y="Score", data=dt)

# %% [markdown]
# We can also directly fit a **polynomial regression model** of second order using the argument **order** and a **logistic** regressin using the argument **logistic=True**

# %%
sns.lmplot(x="PropertyRights", y="Score", data=dt, order = 3)

# %% [markdown]
# or conditioning on other variables using the argument **hue**:

# %%
sns.lmplot(x="PropertyRights", y="Score", hue="Region", data=dt)

# %%
sns.jointplot(x="PropertyRights", y="Score", data=dt, kind="reg")

# %% [markdown]
# If we want only a single density plot of the **score** variable:

# %%
sns.distplot(dt.Score, color="r")

# %% [markdown]
# **Pair plot** considering some variables, i.e. Property Rights, Labor Freedom, Government Integrity, Judical Effectiveness, Fiscal Health, Region and Score:

# %%
dt1 = dt[['PropertyRights', 'LaborFreedom', 'GovernmentIntegrity', 'JudicalEffectiveness','FiscalHealth', "Score", 'Region']]

# %%
matplotlib.rc_file_defaults()
sns.pairplot(dt1, hue="Region")

# %% [markdown]
# # <span style="color:blue"> Linear regression </span>

# %% [markdown]
# Import packages

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %% [markdown]
# Correlation matrix

# %%
corr = dt[['PropertyRights', 'LaborFreedom', 'GovernmentIntegrity', 'JudicalEffectiveness','FiscalHealth', "Score"]].corr()
corr
# Out:
#                       PropertyRights  LaborFreedom  GovernmentIntegrity  \
# PropertyRights              1.000000      0.432746             0.866998
# LaborFreedom                0.432746      1.000000             0.413794
# GovernmentIntegrity         0.866998      0.413794             1.000000
# JudicalEffectiveness        0.826805      0.421694             0.888880
# FiscalHealth                0.329969      0.104431             0.292240
# Score                       0.876601      0.512976             0.818174
#
#                       JudicalEffectiveness  FiscalHealth     Score
# PropertyRights                    0.826805      0.329969  0.876601
# LaborFreedom                      0.421694      0.104431  0.512976
# GovernmentIntegrity               0.888880      0.292240  0.818174
# JudicalEffectiveness              1.000000      0.287380  0.805825
# FiscalHealth                      0.287380      1.000000  0.559395
# ...

# %% [markdown]
# Heatmap of the **correlation matrix**:

# %%
sns.set(rc=rc)
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns)

# %% [markdown]
# We split the dataset into training (0.8) and test set (0.2). We use the function **train_test_split**:

# %%
train, test = train_test_split(dt, test_size=0.2)

# %% [markdown]
# **Linear regression** having as dependent variable the **Score** and PropertyRights, LaborFreedom and FiscalHealth as explicative variables:

# %%
results = smf.ols('Score ~ PropertyRights + LaborFreedom + FiscalHealth', data=train).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Score   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     347.2
# Date:                Mon, 16 Dec 2019   Prob (F-statistic):           5.63e-63
# Time:                        00:30:51   Log-Likelihood:                -365.64
# No. Observations:                 138   AIC:                             739.3
# Df Residuals:                     134   BIC:                             751.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# Residual plots:

# %%
residual = train['Score'].values - results.fittedvalues
plt.scatter(residual, results.fittedvalues)

# %% [markdown]
# We **predict** the score values using the test set:

# %%
pred = results.predict(test)

# %% [markdown]
# Compute the **mean squared error**:

# %%
mean_squared_error(test.Score, pred)
# Out:
# 18.636628729094255

# %% [markdown]
# We try to use a **linear mixed model**, considering as random effects the Region variable.

# %%
md = smf.mixedlm("Score ~ PropertyRights + LaborFreedom + FiscalHealth", train, groups="Region")
mdf = md.fit()
mdf.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#           Mixed Linear Model Regression Results
# ...
# Model:              MixedLM Dependent Variable: Score
# No. Observations:   138     Method:             REML
# No. Groups:         5       Scale:              11.2505
# Min. group size:    14      Likelihood:         -373.5378
# Max. group size:    39      Converged:          Yes
# Mean group size:    27.6
# ---------------------------------------------------------
#                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------
# Intercept      25.440    1.679 15.155 0.000 22.150 28.730
# PropertyRights  0.398    0.020 19.728 0.000  0.359  0.438
# LaborFreedom    0.134    0.025  5.406 0.000  0.085  0.182
# FiscalHealth    0.101    0.010  9.880 0.000  0.081  0.121
# Region Var      1.341    0.414
# ...
#
# """

# %% [markdown]
# See <http://www.statsmodels.org/stable/index.html> for other commands about the linear (mixed) model. Also, <https://www.statsmodels.org/stable/examples/notebooks/generated/mixed_lm_example.html> makes a comparison between R lmer and Statsmodels MixedLM.

# %% [markdown]
# # <span style="color:blue"> Principal Component Analysis </span>

# %% [markdown]
# Import packages:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import numpy as np

# %% [markdown]
# Standardize data:

# %%
features = ['PropertyRights', 'LaborFreedom', 'GovernmentIntegrity', 'JudicalEffectiveness','FiscalHealth']
# Separating out the features
x = dt.loc[:, features].values
# Separating out the target
y = dt.loc[:,'Score'].values
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %% [markdown]
# Perform PCA considering $4$ principal components:

# %%
pca = PCA(4)
projected = pca.fit_transform(x)

# %%
print(x.shape)
print(projected.shape)
# Out:
# (173L, 5L)
# (173L, 4L)

# %% [markdown]
# Plot the first $2$ principal components, we can choose the color using the argument c for the values and cmap for the type and number of different colors:

# %%
plt.scatter(projected[:, 0], projected[:, 1],
            c=projected[:, 1],  cmap=plt.cm.get_cmap('seismic', 10))
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.colorbar()

# %% [markdown]
# We can plot also the first $3$ principal component analysis:

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')
ax.scatter(projected[:, 0], projected[:, 1], projected[:, 2], c=projected[:, 2],
            cmap=plt.cm.get_cmap('seismic', 10))

# %% [markdown]
# and the **explained variance**:

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_)) 
plt.xlabel("Number of component") 
plt.ylabel("Variance explained")
plt.xticks(range(4), [1,2,3,4])
# Out:
# ([<matplotlib.axis.XTick at 0x18c09ac8>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %% [markdown]
# # <span style="color:blue"> Classification analysis </span>

# %% [markdown]
# Doing a classification analysis is very simple thanks to the **sklearn** package. We try to classify the **Region** having the PropertyRights, LaborFreedom, GovernmentIntegrity, JudicalEffectiveness and FiscalHealth informations.

# %% [markdown]
# Load package and functions:

# %%
from sklearn.tree import DecisionTreeClassifier #Decision Tree Classifier function
from sklearn.metrics import classification_report, confusion_matrix #Some functions to check the classification quality

# %% [markdown]
# The **region** of interest are

# %%
print(dt['Region'].unique())
# Out:
# ['Asia-Pacific' 'Europe' 'Middle East and North Africa'
#  'Sub-Saharan Africa' 'Americas']

# %%
sns.countplot(dt['Region'],label="Count")

# %%
dt1 = dt[['Region','PropertyRights', 'LaborFreedom', 'GovernmentIntegrity', 'JudicalEffectiveness','FiscalHealth']]

# %% [markdown]
# Split X and y:

# %%
X = dt1[['PropertyRights', 'LaborFreedom', 'GovernmentIntegrity', 'JudicalEffectiveness','FiscalHealth']]
y = dt1['Region']

# %% [markdown]
# Create train and test set:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %% [markdown]
# **Train** the Decision Tree Classifier:

# %%
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %% [markdown]
# Make **prediction**:

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# Compute the **confusion matrix**:

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[1 2 2 0 1]
#  [3 3 3 1 2]
#  [0 1 4 3 1]
#  [0 2 0 0 1]
#  [0 3 0 0 2]]

# %% [markdown]
# Some **classification metrics**:

# %%
print(classification_report(y_test, y_pred))
# Out:
#                               precision    recall  f1-score   support
#
#                     Americas       0.25      0.17      0.20         6
#                 Asia-Pacific       0.27      0.25      0.26        12
#                       Europe       0.44      0.44      0.44         9
# Middle East and North Africa       0.00      0.00      0.00         3
#           Sub-Saharan Africa       0.29      0.40      0.33         5
#
#                    micro avg       0.29      0.29      0.29        35
#                    macro avg       0.25      0.25      0.25        35
#                 weighted avg       0.29      0.29      0.29        35

# %% [markdown]
# Further details about classification functions and clustering <https://scikit-learn.org/stable/>.
